# %%
def solution(A):
  routem = size(2**(N+M-2))
  routen = size(2**(N+M-2))
  op=[]
  op[0]=1
  while something
    j = j+1
    op[j] = op[j-1]**2
    for i in len(route):
      for h in len(op)/2:
      route[(i-1)+h]=route[(i-1)]
      
      

    pass


solution([4,24, 5, 1, 1, 5, 2, 4, 1, 29])
# Out:
# 24
