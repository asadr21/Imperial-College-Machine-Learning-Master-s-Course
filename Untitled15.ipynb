# %%
import numpy as np

def solution(A, K):
  B=[]
  T=[]
  B.append(A)
  for i in range(K):
    for j in range(len(A)):
      T.append(A[j-1])
      B.append(T)
  return B[i+1]

solution([4, 3, 1, 6, 12], 6)
# Out:
# [12,
#  4,
#  3,
#  1,
#  6,
#  12,
#  4,
#  3,
#  1,
#  6,
#  12,
#  4,
#  3,
#  1,
#  6,
#  12,
#  4,
#  3,
#  1,
#  6,
#  12,
#  4,
#  3,
#  1,
#  6,
#  12,
#  4,
#  3,
#  1,
#  6]
